# %% [markdown]
# # Image Arithmetics

# %% [markdown]
# You can do some meaningful arithmetics on images to get various results. For example you can add images, subtract them, or even multiply them.
#
# Now, we are going to test some of these mathematical operations.

# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
live = imread('C:/Users/mstof/OneDrive/Desktop/Sample/Apple___Black_rot/0e84adc9-3e97-48e2-b1fd-7d04f9e92cb0___JR_FrgE.S 2949.JPG')
mask = imread('C:/Users/mstof/OneDrive/Desktop/Sample/Apple___Black_rot/1bb4d1d5-ca06-49b6-8f89-ed0d6c1d68af___JR_FrgE.S 8777.JPG')

plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(live, cmap='gray')
plt.subplot(122), plt.imshow(mask, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(live, cmap='gray')
plt.subplot(122), plt.imshow(live - 20, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(131), plt.imshow(mask - live, cmap='gray')
plt.subplot(132), plt.imshow(-(mask - live + 128), cmap='gray')
plt.subplot(133), plt.imshow(mask - live + 128, cmap='gray')
plt.show()

# %%
shaded = imread('C:/Users/mstof/OneDrive/Desktop/Sample/Apple___Black_rot/0e84adc9-3e97-48e2-b1fd-7d04f9e92cb0___JR_FrgE.S 2949.JPG')
shading = imread('C:/Users/mstof/OneDrive/Desktop/Sample/Apple___Black_rot/1bb4d1d5-ca06-49b6-8f89-ed0d6c1d68af___JR_FrgE.S 8777.JPG')


plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(shaded, cmap='gray')
plt.subplot(122), plt.imshow(shading, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
plt.subplot(122), plt.imshow(shaded, cmap='gray')
plt.show()
# Out:
# C:\Users\mstof\AppData\Local\Temp\ipykernel_9252\1289966496.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
# C:\Users\mstof\AppData\Local\Temp\ipykernel_9252\1289966496.py:2: RuntimeWarning: invalid value encountered in multiply
#   plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Test on the X-ray dental image
xray = imread('C:/Users/mstof/OneDrive/Desktop/Sample/Apple___Black_rot/0e84adc9-3e97-48e2-b1fd-7d04f9e92cb0___JR_FrgE.S 2949.JPG')
mask_xray = imread('C:/Users/mstof/OneDrive/Desktop/Dataset/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Peach___healthy/1e456a81-ec19-43b9-8502-73e1996a0ead___Rutg._HL 3651.jpg')

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(xray, cmap='gray')
plt.subplot(122), plt.imshow(mask_xray, cmap='gray')
plt.show()

# %%
plt.figure()
plt.imshow(np.multiply(xray, mask_xray/255), cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Test on another image
scan = imread('C:/Users/mstof/Downloads/Fertilizers_Recommendation_ System_For_Disease_ Prediction/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Corn_(maize)___Northern_Leaf_Blight/0a62fe5a-22db-42e2-bca0-53a8dcfd8129___RS_NLB 0810.JPG')
print(scan.shape)
# Out:
# (256, 256, 3)

# %%
# Showing the body scan image
plt.figure(figsize=(7, 7))
plt.imshow(scan, cmap='gray')
plt.show()

# %% [markdown]
# # Pixel relationships

# %% [markdown]
# ![4,8%20neighbourhood.gif](attachment:4,8%20neighbourhood.gif)

# %% [markdown]
# # Usual processes in DIP

# %% [markdown]
# # Pixel (Point) processing

# %% [markdown]
# Only individual pixels are entered into a process. The output is dependent on the single pixel values.
#
# Some of this kind of processes are:
#
# Histogram Processing
#
# Contrast Enhancement
# Histogram Equalization
# Histogram Matching
# Histogram Strtching
# Intensity Transformations
#
# Negative of an image
# Log transformation
# n-th power transformation
# piecewise transformations
# Region (Neighborhood) processing
# A region (area) of pixels are entered into a process. The output is dependent on the values of entire region.
#
# A common example of this kind of process includes Spatial Filtering and Morphological Operators, which are:
#
# Average filtering,
# Median filtering,
# Sharpening filters,
# Edge detectors,
# Morphological Operations

# %% [markdown]
# # Histogram of an image

# %% [markdown]
# ![a.gif](attachment:a.gif)

# %% [markdown]
# ![b.jpg](attachment:b.jpg)

# %% [markdown]
# ![c.jpg](attachment:c.jpg)

# %% [markdown]
# ![d.jpg](attachment:d.jpg)

# %%
plt.figure(figsize=(10, 10))
plt.subplot(211), plt.imshow(xray, cmap='gray')
plt.subplot(212), plt.plot(np.histogram(xray, bins=256)[0])
plt.show()
